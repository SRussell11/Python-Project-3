# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# %matplotlib inline

# %%
##Import csv file
df = pd.read_csv (r'/content/NYPD_Arrest_Data__Year_to_Date_.csv')
df
# Out:
#         ARREST_KEY ARREST_DATE  PD_CD                         PD_DESC  KY_CD  \
# 0        238013474  12/18/2021  157.0                          RAPE 1  104.0
# 1        236943583  11/25/2021  263.0                     ARSON 2,3,4  114.0
# 2        234938876  10/14/2021  594.0                     OBSCENITY 1  116.0
# 3        234788259  10/11/2021  263.0                     ARSON 2,3,4  114.0
# 4        234188790  09/28/2021  578.0                             NaN    NaN
# ...            ...         ...    ...                             ...    ...
# 155502   222884924  01/10/2021  397.0  ROBBERY,OPEN AREA UNCLASSIFIED  105.0
# 155503   223918625  02/03/2021  792.0        WEAPONS POSSESSION 1 & 2  118.0
# 155504   224323770  02/13/2021  101.0                       ASSAULT 3  344.0
# 155505   222599533  01/04/2021  792.0        WEAPONS POSSESSION 1 & 2  118.0
# 155506   224056881  02/06/2021  268.0              CRIMINAL MIS 2 & 3  121.0
#
# ...

# %%
##Pull total columns and rows in the dataset
df.shape
# Out:
# (155507, 19)

# %%
##Run descriptive stats on the data 
df.head(10)
# Out:
#    ARREST_KEY ARREST_DATE  PD_CD      PD_DESC  KY_CD   OFNS_DESC    LAW_CODE  \
# 0   238013474  12/18/2021  157.0       RAPE 1  104.0        RAPE  PL 1303501
# 1   236943583  11/25/2021  263.0  ARSON 2,3,4  114.0       ARSON  PL 1501500
# 2   234938876  10/14/2021  594.0  OBSCENITY 1  116.0  SEX CRIMES  PL 2631100
# 3   234788259  10/11/2021  263.0  ARSON 2,3,4  114.0       ARSON  PL 1501001
# 4   234188790  09/28/2021  578.0          NaN    NaN         NaN  PL 2223001
# 5   234117071  09/27/2021  157.0       RAPE 1  104.0        RAPE  PL 1303501
# 6   233755503  09/18/2021  579.0          NaN    NaN         NaN  PL 2224002
# 7   233740512  09/18/2021  157.0       RAPE 1  104.0        RAPE  PL 1303502
# 8   233697123  09/17/2021  157.0       RAPE 1  104.0        RAPE  PL 1303501
# 9   233381184  09/10/2021  578.0          NaN    NaN         NaN  PL 2223001
#
#   LAW_CAT_CD ARREST_BORO  ARREST_PRECINCT  JURISDICTION_CODE AGE_GROUP  \
# ...

# %%
df.tail(10)
# Out:
#         ARREST_KEY ARREST_DATE  PD_CD                         PD_DESC  KY_CD  \
# 155497   224526582  02/18/2021   49.0          U.S. CODE UNCLASSIFIED  995.0
# 155498   222606798  01/05/2021  101.0                       ASSAULT 3  344.0
# 155499   222619887  01/05/2021  139.0             MURDER,UNCLASSIFIED  101.0
# 155500   222488090  01/01/2021  268.0              CRIMINAL MIS 2 & 3  121.0
# 155501   223912130  02/03/2021  339.0  LARCENY,PETIT FROM OPEN AREAS,  341.0
# 155502   222884924  01/10/2021  397.0  ROBBERY,OPEN AREA UNCLASSIFIED  105.0
# 155503   223918625  02/03/2021  792.0        WEAPONS POSSESSION 1 & 2  118.0
# 155504   224323770  02/13/2021  101.0                       ASSAULT 3  344.0
# 155505   222599533  01/04/2021  792.0        WEAPONS POSSESSION 1 & 2  118.0
# 155506   224056881  02/06/2021  268.0              CRIMINAL MIS 2 & 3  121.0
#
#                              OFNS_DESC    LAW_CODE LAW_CAT_CD ARREST_BORO  \
# ...

# %%
##Pull type of all columns in the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155507 entries, 0 to 155506
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   ARREST_KEY                155507 non-null  int64
#  1   ARREST_DATE               155507 non-null  object
#  2   PD_CD                     155478 non-null  float64
#  3   PD_DESC                   155404 non-null  object
#  4   KY_CD                     155404 non-null  float64
#  5   OFNS_DESC                 155404 non-null  object
#  6   LAW_CODE                  155507 non-null  object
#  7   LAW_CAT_CD                154114 non-null  object
#  8   ARREST_BORO               155507 non-null  object
#  9   ARREST_PRECINCT           155507 non-null  int64
#  10  JURISDICTION_CODE         155507 non-null  int64
#  11  AGE_GROUP                 155507 non-null  object
#  12  PERP_SEX                  155507 non-null  object
# ...

# %%
##Check for duplicated data
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 155502    False
# 155503    False
# 155504    False
# 155505    False
# 155506    False
# Length: 155507, dtype: bool

# %%
##Check for overall null values in the dataset
print(df.isnull().sum())
# Out:
# ARREST_KEY                     0
# ARREST_DATE                    0
# PD_CD                         29
# PD_DESC                      103
# KY_CD                        103
# OFNS_DESC                    103
# LAW_CODE                       0
# LAW_CAT_CD                  1393
# ARREST_BORO                    0
# ARREST_PRECINCT                0
# JURISDICTION_CODE              0
# AGE_GROUP                      0
# PERP_SEX                       0
# PERP_RACE                      0
# X_COORD_CD                     0
# Y_COORD_CD                     0
# Latitude                       0
# Longitude                      0
# New Georeferenced Column       0
# dtype: int64

# %%
#Pull descriptive stats on the numeric fields in the dataset 
df.describe()
# Out:
#          ARREST_KEY          PD_CD          KY_CD  ARREST_PRECINCT  \
# count  1.555070e+05  155478.000000  155404.000000    155507.000000
# mean   2.304676e+08     407.828066     244.962974        62.850322
# std    4.628028e+06     275.739138     150.334545        35.258605
# min    2.224711e+08       0.000000     101.000000         1.000000
# 25%    2.263289e+08     113.000000     111.000000        34.000000
# 50%    2.306202e+08     339.000000     235.000000        62.000000
# 75%    2.344524e+08     705.000000     344.000000       101.000000
# max    2.385139e+08     997.000000     995.000000       123.000000
#
#        JURISDICTION_CODE    X_COORD_CD     Y_COORD_CD       Latitude  \
# count      155507.000000  1.555070e+05  155507.000000  155507.000000
# mean            0.912486  1.004996e+06  208163.457555      40.737994
# std             7.894204  2.152869e+04   29904.384015       0.082086
# min             0.000000  9.142140e+05  121312.000000      40.499401
# ...

# %%
##Pull all column names available within the dataset
df.columns
# Out:
# Index(['ARREST_KEY', 'ARREST_DATE', 'PD_CD', 'PD_DESC', 'KY_CD', 'OFNS_DESC',
#        'LAW_CODE', 'LAW_CAT_CD', 'ARREST_BORO', 'ARREST_PRECINCT',
#        'JURISDICTION_CODE', 'AGE_GROUP', 'PERP_SEX', 'PERP_RACE', 'X_COORD_CD',
#        'Y_COORD_CD', 'Latitude', 'Longitude', 'New Georeferenced Column'],
#       dtype='object')

# %%
##Identify the top 20 crimes reported in the dataset- Assault 3 and Related offenses was the highest 
df.OFNS_DESC.value_counts().iloc[:20].sort_values().plot(kind="barh",title="Types of Crimes")

# %%
##Identify the total count of crimes within the age groups- 25-44 had the highest total
df['AGE_GROUP'].value_counts().sort_values().plot(kind="barh",title='Total Crimes by Age Group')

# %%
#Identify the total count of crimes within the genders- Males had the highest total crimes. 
df['PERP_SEX'].value_counts().sort_values().plot(kind="barh",title='Total Crimes by Gender')

# %%
##Group by Age Group and Race
df1 = df.groupby(['AGE_GROUP','PERP_RACE']).size()
df1
# Out:
# AGE_GROUP  PERP_RACE
# 18-24      AMERICAN INDIAN/ALASKAN NATIVE       99
#            ASIAN / PACIFIC ISLANDER           1367
#            BLACK                             15416
#            BLACK HISPANIC                     3040
#            UNKNOWN                             107
#            WHITE                              1788
#            WHITE HISPANIC                     7134
# 25-44      AMERICAN INDIAN/ALASKAN NATIVE      257
#            ASIAN / PACIFIC ISLANDER           4884
#            BLACK                             42585
#            BLACK HISPANIC                     7890
#            UNKNOWN                             357
#            WHITE                             10083
#            WHITE HISPANIC                    22794
# 45-64      AMERICAN INDIAN/ALASKAN NATIVE       74
#            ASIAN / PACIFIC ISLANDER           1971
#            BLACK                             15171
#            BLACK HISPANIC                     1968
# ...

# %%
##Find outliers within age group and race
sns.boxplot(x=df1)

# %%
##Question: What age group had the most arrests for Arson?

# %%
##Drop columns
drop_cols=['PERP_SEX', 'PERP_RACE','X_COORD_CD','Y_COORD_CD', 'Latitude', 'Longitude', 'New Georeferenced Column','PD_CD','PD_DESC', 'KY_CD','LAW_CODE', 'LAW_CAT_CD','JURISDICTION_CODE','ARREST_BORO', 'ARREST_PRECINCT','ARREST_KEY', 'ARREST_DATE']
df.drop(drop_cols,inplace=True,axis=1)
df
# Out:
#                              OFNS_DESC AGE_GROUP
# 0                                 RAPE     18-24
# 1                                ARSON     25-44
# 2                           SEX CRIMES     25-44
# 3                                ARSON     18-24
# 4                                  NaN     25-44
# ...                                ...       ...
# 155502                         ROBBERY     45-64
# 155503               DANGEROUS WEAPONS     18-24
# 155504    ASSAULT 3 & RELATED OFFENSES     45-64
# 155505               DANGEROUS WEAPONS     25-44
# 155506  CRIMINAL MISCHIEF & RELATED OF     18-24
#
# [155507 rows x 2 columns]

# %%
##Look for the count of null values in the columns that remain
print(df.isnull().sum())
# Out:
# OFNS_DESC    103
# AGE_GROUP      0
# dtype: int64

# %%
##Replace Null values
df['OFNS_DESC'].fillna('UNKNOWN/NOT AVAILABLE/NOT REPORTED',inplace=True)
df
# Out:
#                                  OFNS_DESC AGE_GROUP
# 0                                     RAPE     18-24
# 1                                    ARSON     25-44
# 2                               SEX CRIMES     25-44
# 3                                    ARSON     18-24
# 4       UNKNOWN/NOT AVAILABLE/NOT REPORTED     25-44
# ...                                    ...       ...
# 155502                             ROBBERY     45-64
# 155503                   DANGEROUS WEAPONS     18-24
# 155504        ASSAULT 3 & RELATED OFFENSES     45-64
# 155505                   DANGEROUS WEAPONS     25-44
# 155506      CRIMINAL MISCHIEF & RELATED OF     18-24
#
# [155507 rows x 2 columns]

# %%
##Confirm there are no more null values in the dataset
print(df.isnull().sum())
# Out:
# OFNS_DESC    0
# AGE_GROUP    0
# dtype: int64

# %%
##Rename the necessary columns
df.rename(columns={'OFNS_DESC':'OFFENSE_DESC'},inplace=True)
df
# Out:
#                               OFFENSE_DESC AGE_GROUP
# 0                                     RAPE     18-24
# 1                                    ARSON     25-44
# 2                               SEX CRIMES     25-44
# 3                                    ARSON     18-24
# 4       UNKNOWN/NOT AVAILABLE/NOT REPORTED     25-44
# ...                                    ...       ...
# 155502                             ROBBERY     45-64
# 155503                   DANGEROUS WEAPONS     18-24
# 155504        ASSAULT 3 & RELATED OFFENSES     45-64
# 155505                   DANGEROUS WEAPONS     25-44
# 155506      CRIMINAL MISCHIEF & RELATED OF     18-24
#
# [155507 rows x 2 columns]

# %%
##Filter out Arson Offense and age group 
OFFENSE_BY_AGE = df[(df['OFFENSE_DESC']=='ARSON') & (df['AGE_GROUP'])]
OFFENSE_BY_AGE
# Out:
#        OFFENSE_DESC AGE_GROUP
# 1             ARSON     25-44
# 3             ARSON     18-24
# 822           ARSON     25-44
# 1378          ARSON     18-24
# 1822          ARSON     25-44
# ...             ...       ...
# 151118        ARSON     18-24
# 151876        ARSON     25-44
# 152333        ARSON     25-44
# 153674        ARSON     25-44
# 154375        ARSON     18-24
#
# [122 rows x 2 columns]

# %%
##Pull the count of Arson by Age group
df_age=OFFENSE_BY_AGE["AGE_GROUP"].value_counts()
df_age
# Out:
# 25-44    74
# 45-64    24
# 18-24    16
# 65+       6
# <18       2
# Name: AGE_GROUP, dtype: int64

# %%
##Create dataframe to summarize the total arson offenseby age group
data=[['<18',2],['18-24',16],['25-44',74],['45-65',24],['65+',6]]
df_arson_by_age_group=pd.DataFrame(data,columns=['Age_Group','Total'])
print(df_arson_by_age_group)
# Out:
#   Age_Group  Total
# 0       <18      2
# 1     18-24     16
# 2     25-44     74
# 3     45-65     24
# 4       65+      6

# %%
##Bargraph showing the total arson offense by age group
sns.barplot(x='Age_Group',y='Total', data=df_arson_by_age_group)

# %%
##Observations: 
1. Assault 3 and Related offenses were the highest in NY overall
2. Total crimes was higher within males than females.
3. The age group with the highest offense of Arson is 25-44 with under 18 being the lowest.
